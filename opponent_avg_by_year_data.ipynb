# %%
import pandas as pd
import os

# Directory where the CSV files are located
directory = r'C:\Users\yonatanam\Desktop\NBA\Data'

# List all CSV files in the directory
csv_files = [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('_Opp.csv')]

# Initialize an empty list to store DataFrames
dfs = []

# Loop through each CSV file
for file in csv_files:
    # Extract year from the file name
    year = os.path.basename(file).split('_')[0]
    
    # Read CSV file
    df = pd.read_csv(file)
    
    # Add a new column 'Year' with the extracted year
    df['Year'] = year
    
    # Append the DataFrame to the list
    dfs.append(df)

# Concatenate all DataFrames into one
opponent_avg_by_year_data = pd.concat(dfs, ignore_index=True)

#the combined DataFrame

opponent_avg_by_year_data
# Out:
#        Rk                  Team   G     MP    FG   FGA    FG%    3P   3PA  \
# 0     1.0      Detroit Pistons*  82  242.7  33.5  76.5  0.438   3.5  10.2
# 1     2.0      New Jersey Nets*  82  240.9  33.6  78.8  0.427   5.2  14.5
# 2     3.0    San Antonio Spurs*  82  241.8  34.9  81.7  0.427   4.3  12.7
# 3     4.0            Miami Heat  82  241.8  33.1  75.7  0.437   5.0  14.0
# 4     5.0  New Orleans Hornets*  82  242.7  34.8  79.5  0.438   4.1  12.2
# ..    ...                   ...  ..    ...   ...   ...    ...   ...   ...
# 644  27.0       Detroit Pistons  82  241.5  43.1  88.1  0.489  12.0  33.3
# 645  28.0       Houston Rockets  82  240.9  42.4  88.1  0.482  14.5  38.8
# 646  29.0        Indiana Pacers  82  240.9  43.3  89.3  0.485  12.4  33.3
# 647  30.0     San Antonio Spurs  82  242.1  46.1  91.0  0.507  12.6  32.3
# 648   NaN        League Average  82  241.8  42.0  88.3  0.475  12.3  34.2
#
#        3P%  ...   ORB   DRB   TRB   AST  STL  BLK   TOV    PF    PTS  Year
# ...

# %%
opponent_avg_by_year_data.to_csv(os.path.join(directory, 'opponent_avg_by_year_data.csv'), index=False)
